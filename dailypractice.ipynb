# %%
#variables
#1.Create a variable name and store your name in it. Print the value.
a="sneha"
print(a)
# Out:
# sneha

# %%
#2.Create variables age and city and print them in one sentence.
age=str(18)
city=" banglore "
print(age + city)
# Out:
# 18 banglore

# %%
#3.Store two numbers in variables and print their sum.
a=10
b=5
print(a+b)
# Out:
# 15

# %%
#4.Swap the values of two variables without using a third variable.
a=5
b=10
a,b=b,a
print(a)
print(b)
# Out:
# 10
# 5

# %%
#Input & Output
#1.Take the user's name as input and print: Hello, <name>!
print("hello,")
user=input("name:")
print(user)
# Out:
# hello,
# sneha

# %%
#2.Take the user's age as input and print how old they are.
user=input("age:")
print(user)
print("years old they are.")
# Out:
# 20
# years old they are.

# %%
#3.Take two numbers as input and print their sum.
a=int(input("num1:"))
b=int(input("num2:"))
print(a)
print(b)
print(a+b)
# Out:
# 9
# 6
# 15

# %%
#4.Take a student's name and marks as input and display them neatly.
student=input("name:")
Marks=input("marks:")
print(student)
print(Marks)
# Out:
# sneha
# 40

# %%
student=input("enter a student name:")
maths=int(input("enter maths:"))
science=int(input("enter science"))
english=int(input("enter english"))
print(("Name:"),student)
print(("maths:"),maths)
print(("science:"),science)
print(("english:"),english)
# Out:
# Name: Nikhil
# maths: 50
# science: 49
# english: 46

# %%
#Arithmetic Operators
#1.Take two numbers and print their addition, subtraction, multiplication, and division.
a=5
b=10
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
# Out:
# 15
# -5
# 50
# 0.5
# 0

# %%
#2.Find the remainder when one number is divided by another.
a=10
b=5
print(a/b)
print(a%b)
# Out:
# 2.0
# 0

# %%
#3.Calculate the square of a number entered by the user.
num=int(input("enter a square number:"))
print(num)
square=num*num
print(square)
# Out:
# 5
# 25

# %%
#4 Calculate the area of a rectangle using length and width entered by the user.
length=float(input("enter a length:"))
width=float(input("enter a width:"))
area=length*width
print("Area:",area)
# Out:
# Area: 42.0

# %%
#5 Calculate the perimeter of a rectangle.
length=float(input("enter a length:"))
breadth=float(input("enter a breadth:"))
perimeter=2*(length+breadth)
print("Perimeter:",perimeter)
# Out:
# Perimeter: 22.0

# %%
#6 Find the average of three numbers entered by the user.
a=int(input("enter a number1:"))
b=int(input("enter a number2:"))
c=int(input("enter a number3:"))
average=(a+b+c)/3
print("Average:",average)
# Out:
# Average: 5.0

# %%
#Data Types
#1 Create variables of type int, float, str, and bool and print their types using type().
a=10
b=10.2
c="Sneha"
d=True
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
#2 Take a number as input and convert it to a float.
a=float(input("enter a number:"))
print(a)
# Out:
# 5.0

# %%
#3 Take a decimal number as input and convert it to an integer.
num=float(input("enter a number:"))
print(int(num))
# Out:
# 5

# %%
#4 Store your name, age, and height in variables and print their data types.
name="Sneha"
age=20
height=5.5
print(type(name))
print(type(age))
print(type(height))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
#Ask the user for their birth year and calculate their age.
birth_year=int(input("enter birth year:"))
age=abs(birth_year-2026)
print(age)
# Out:
# 21

# %%
#3Calculate the total price of 5 items if the user enters the price of one item.
price=int(input("enter price of one item :"))
total=price*5
print("total price:",total)
# Out:
# total price: 150

# %%
#Take two numbers and find their product and quotient.
num1=int(input("enter first number:"))
num2=int(input("enter second number:"))
product=num1*num2
print("product:",product)
quotient=num1/num2
print("quotient:",quotient)
# Out:
# product: 50
# quotient: 0.5

# %%
#Create a program that takes a student's name and three subject marks, then calculates the total and average marks.
name=("enter a student name:")
m1=int(input("enter first number:"))
m2=int(input("enter second number:"))
m3=int(input("enter third number:"))
total=m1+m2+m3
average=total/3
print("Total:",total)
print("Average:",average)
# Out:
# Total: 130
# Average: 43.333333333333336
